# %%
#Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?
#Ans:   A probability distribution is a mathematical function that describes the probability of different possible outcomes for an experiment.
#       Even though the values in probability distribution are random, they are not completely unpredictable. 
#       The probability distribution provides information about the likelihood of different outcomes, therefore this information can be used to make predictions.

# %%
#Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is one? Why are the latter considered “good enough”?
#Ans:   Yes! there is a difference between true random number and pseudo-random number. True random numbers are generated by physical process, that are unpredictable.
#       Pseudo-random numbers are generated by algorithms that use mathematical formulaes to produce a sequence of numbers that appears to be random.
#       The Pseudo-random numbers are better than true random numbers. They are much faaster and easier to generate.

# %%
#Q3. What are the two main factors that influence the behaviour of a "normal" probability distribution?
#Ans:   The factors that influence behavior of a normal probability distribution are:
#       Mean : It is average value of the distribution
#       Standard Deviation: it is the measure of spread of the values in a distribution.

# %%
#Q4.  Provide a real-life example of a normal distribution.
#Ans:   Some real life example of normal distribution are:
#           Height of people
#           Scores of a standardized test
#           amount of rainfall in any area
#           number of accidents in an area and many more.

# %%
#Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?
#Ans:   As the number of trial grows, the probablities distribution is expected to become more and more stable. 
#       It tends to get closer to the mean value as the number of trial grows.

# %%
#Q6. What kind of object can be shuffled by using random.shuffle?
#Ans:   By using random.shuffle() function any sequence object can be shuffled. It uses Fisher-Yates algorithm to shuffle the elements in sequence object.

# %%
#Q7. Describe the math package's general categories of functions.
#Ans:   The math package in pyhton provides the mathematical operations functions. The functions provided by maths method are:
#       Arithmetic functions: add(), subtract(), multiply(), divide()
#       Trigonometric functions: sin(), cos(), tan()
#       Exponential and logarithmic function: exp(), log()
#       Statistical functions: mean(), median(), mode()
#       Mathematical constants: pi(), e()

# %%
#Q8. What is the relationship between exponentiation and logarithms?
#Ans:   Exponential function is inverse of logarithmic function.

# %%
#Q9. What are the three logarithmic functions that Python supports?
#Ans:   The three logarithmic functions that pyhton support are:    log(), log10(), log2().
